# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data2 = pd.read_csv("Data_Cleaned.csv")

# %%
data2.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean   150.826667   54.410000    0.683333  131.770000  245.880000    0.146667
# std     87.721454    9.053274    0.465953   17.658705   48.591178    0.354364
# min      0.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     74.750000   47.750000    0.000000  120.000000  211.000000    0.000000
# 50%    150.500000   56.000000    1.000000  130.000000  241.500000    0.000000
# 75%    226.250000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    302.000000   77.000000    1.000000  200.000000  417.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.986667  149.666667    0.326667    1.041333    1.600000    0.693333
# ...

# %%
print(data2[["Age","RestBP","Chol","MaxHR","Oldpeak"]].describe())
# Out:
#               Age      RestBP        Chol       MaxHR     Oldpeak
# count  300.000000  300.000000  300.000000  300.000000  300.000000
# mean    54.410000  131.770000  245.880000  149.666667    1.041333
# std      9.053274   17.658705   48.591178   22.891241    1.164881
# min     29.000000   94.000000  126.000000   71.000000    0.000000
# 25%     47.750000  120.000000  211.000000  133.750000    0.000000
# 50%     56.000000  130.000000  241.500000  152.500000    0.800000
# 75%     61.000000  140.000000  275.000000  166.000000    1.600000
# max     77.000000  200.000000  417.000000  202.000000    6.200000

# %%
print(data2.columns)
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal',
#        'Target'],
#       dtype='object')

# %%
print(len(data2))
# Out:
# 300

# %%
print(data2[data2.isnull().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Sex, ChestPain, RestBP, Chol, Fbs, RestECG, MaxHR, ExAng, Oldpeak, Slope, Ca, Thal, Target]
# Index: []

# %%
print(data2.duplicated().sum())
# Out:
# 0

# %%
print(data2["Sex"].value_counts())
# Out:
# Sex
# 1    205
# 0     95
# Name: count, dtype: int64

# %%
print(data2.groupby("Sex")["Age"].mean())
# Out:
# Sex
# 0    55.631579
# 1    53.843902
# Name: Age, dtype: float64

# %%
print(data2["ChestPain"].unique())
# Out:
# ['typical' 'asymptomatic' 'nonanginal' 'nontypical']

# %%
    print(data2[data2["Chol"] > 360])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 48           48   65    0    nonanginal     140   417    1        2    157
# 120         121   63    0  asymptomatic     150   407    0        2    154
# 171         173   62    0  asymptomatic     140   394    0        2    157
# 179         181   56    0  asymptomatic     134   409    0        2    150
#
#      ExAng  Oldpeak  Slope  Ca        Thal  Target
# 48       0      0.8      1   1      normal       0
# 120      0      4.0      2   3  reversable       1
# 171      0      1.2      2   0      normal       0
# 179      1      1.9      2   2  reversable       1

# %%
print(pd.crosstab(data2["RestBP"] > 170,data2["Target"]))
# Out:
# Target    0    1
# RestBP
# False   159  132
# True      3    6

# %%
print(pd.crosstab(data2["Target"], data2["Sex"]).loc[1].sum())
# Out:
# 138

# %%
print(data2.groupby(["Age"]).mean(numeric_only=True))
# Out:
#      Unnamed: 0       Sex      RestBP        Chol       Fbs   RestECG  \
# Age
# 29   132.000000  1.000000  130.000000  204.000000  0.000000  2.000000
# 34   163.000000  0.500000  118.000000  196.000000  0.000000  1.000000
# 35   176.500000  0.750000  126.500000  213.750000  0.000000  0.500000
# 37   106.500000  0.500000  125.000000  232.500000  0.000000  0.000000
# 38   256.500000  1.000000  129.000000  203.000000  0.000000  0.000000
# 39   172.500000  0.500000  122.500000  239.750000  0.000000  0.500000
# 40   112.666667  1.000000  134.000000  196.333333  0.000000  0.666667
# 41   158.100000  0.600000  119.000000  220.700000  0.000000  0.800000
# 42   197.750000  0.750000  127.000000  246.750000  0.125000  0.500000
# 43   142.375000  0.750000  126.375000  256.750000  0.250000  0.750000
# 44   122.454545  0.818182  120.727273  221.363636  0.000000  0.727273
# 45   165.250000  0.625000  122.375000  247.375000  0.000000  1.500000
# ...

# %%
data2["RestBP"].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
plt.boxplot(data2["Chol"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22e07c05310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22e07c05590>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22e07c051d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22e07c05810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22e07c05950>],
#  'means': []}

# %%
data2.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# Target        0
# dtype: int64

# %%
data2[["Sex","Target"]].hist()
# Out:
# array([[<Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Target'}>]], dtype=object)

# %%
data2.plot( x='Sex', y='Target', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data2["RestBP"].hist()
# Out:
# <Axes: >

# %%
#data2 = data.drop(152, axis= 0) This before removing the Null 
print(data2[data2["Chol"] > 360])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 48           48   65    0    nonanginal     140   417    1        2    157
# 120         121   63    0  asymptomatic     150   407    0        2    154
# 171         173   62    0  asymptomatic     140   394    0        2    157
# 179         181   56    0  asymptomatic     134   409    0        2    150
#
#      ExAng  Oldpeak  Slope  Ca        Thal  Target
# 48       0      0.8      1   1      normal       0
# 120      0      4.0      2   3  reversable       1
# 171      0      1.2      2   0      normal       0
# 179      1      1.9      2   2  reversable       1

# %%
print(data2[data2["Chol"] > 360])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 48           48   65    0    nonanginal     140   417    1        2    157
# 120         121   63    0  asymptomatic     150   407    0        2    154
# 171         173   62    0  asymptomatic     140   394    0        2    157
# 179         181   56    0  asymptomatic     134   409    0        2    150
#
#      ExAng  Oldpeak  Slope  Ca        Thal  Target
# 48       0      0.8      1   1      normal       0
# 120      0      4.0      2   3  reversable       1
# 171      0      1.2      2   0      normal       0
# 179      1      1.9      2   2  reversable       1

# %%
print(data2[data2["RestBP"]> 170])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 14           14   52    1    nonanginal     172   199    1        0    162
# 83           83   68    1    nonanginal     180   274    1        2    150
# 125         126   56    0  asymptomatic     200   288    1        2    133
# 170         172   59    0  asymptomatic     174   249    0        0    143
# 181         183   59    1       typical     178   270    0        2    145
# 186         188   54    1    nontypical     192   283    0        2    195
# 199         201   64    0  asymptomatic     180   325    0        0    154
# 211         213   66    0  asymptomatic     178   228    1        0    165
# 229         231   55    0  asymptomatic     180   327    0        1    117
#
#      ExAng  Oldpeak  Slope  Ca        Thal  Target
# 14       0      0.5      1   0  reversable       0
# 83       1      1.6      2   0  reversable       1
# 125      1      4.0      3   2  reversable       1
# ...

# %%
data2[["MaxHR","Oldpeak"]].hist(edgecolor = 'black')
# Out:
# array([[<Axes: title={'center': 'MaxHR'}>,
#         <Axes: title={'center': 'Oldpeak'}>]], dtype=object)

# %%
print(len(data2[(data2["Oldpeak"] > 2)]))
# Out:
# 50

# %%
print(len(data2[data2["Oldpeak"]>= 4]))
# Out:
# 8

# %%
sns.boxplot(x="Sex", y="RestBP", data=data2)
# Out:
# <Axes: xlabel='Sex', ylabel='RestBP'>

# %%
print(len(data2[data2["Chol"]>240]))
# Out:
# 151

# %%
print(len(data2[(data2["Chol"] >= 240) & (data2["Target"] == 1) & (data2["Sex"] == 1)] ))
# Out:
# 62

# %%
print(data2.corr(numeric_only=True))
# Out:
#             Unnamed: 0       Age       Sex    RestBP      Chol       Fbs  \
# Unnamed: 0    1.000000 -0.001649 -0.078180 -0.021696 -0.100646 -0.051576
# Age          -0.001649  1.000000 -0.092008  0.290482  0.193037  0.124015
# Sex          -0.078180 -0.092008  1.000000 -0.070258 -0.184852  0.039160
# RestBP       -0.021696  0.290482 -0.070258  1.000000  0.159237  0.177507
# Chol         -0.100646  0.193037 -0.184852  0.159237  1.000000  0.025887
# Fbs          -0.051576  0.124015  0.039160  0.177507  0.025887  1.000000
# RestECG      -0.144770  0.145054  0.034149  0.150788  0.161094  0.081458
# MaxHR        -0.111265 -0.399484 -0.055082 -0.045059 -0.015936 -0.011682
# ExAng        -0.008360  0.096583  0.138020  0.063514  0.083917  0.012590
# Oldpeak      -0.123088  0.202114  0.101217  0.190675  0.037484  0.005520
# Slope        -0.033886  0.159861  0.034873  0.119747 -0.018660  0.055026
# Ca            0.056435  0.336687  0.097225  0.098465  0.129483  0.163875
# ...
